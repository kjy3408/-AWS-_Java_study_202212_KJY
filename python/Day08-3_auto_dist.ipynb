# %%
import numpy as np
import math

def my_split(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list

def split_len(data_list):
    len_list=[]
    for e in data_list:
        len_list.append(len(e))
    print(set(len_list))
    if len(set(len_list))>1:
        for i in set(len_list):
            print(i, len_list.count(i))

def dist_np(p1, p2): #  [3,10]  [5,25]
    return math.sqrt(sum((p2-p1)**2))

# %%
csv_data=[]
with open('전국자동차정비업체표준데이터.csv') as f:
    for line in f:
        csv_data.append(line.split(','))

print(csv_data[:3])
# Out:
# [['자동차정비업체명', '자동차정비업체종류', '소재지도로명주소', '소재지지번주소', '위도', '경도', '사업등록일자', '면적', '영업상태', '폐업일자', '휴업시작일자', '휴업종료일자', '운영시작시각', '운영종료시각', '전화번호', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드', '제공기관명\n'], ['서면카센타', '3', '경상북도 울진군 금강송면 불영계곡로 1684', '', '36.93385095', '129.2462157', '2006-11-27', '650', '1', '', '', '', '09:00', '18:00', '054-781-0744', '경상북도 울진군', '054-789-6636', '2021-10-22', '1613000', '국토교통부\n'], ['주식회사 이에스티', '1', '충청북도 진천군 이월면 이덕로 267', '', '36.9337494', '127.4605018', '2016-02-17', '8821.34', '1', '', '', '', '09:00', '18:00', '043-532-8228', '충청북도 진천군', '043-539-3073', '2021-10-22', '1613000', '국토교통부\n']]

# %%
car_list_we=[]
car_list_gu=[]
for i in csv_data:
    car_list_gu.append(i[5:6])
    car_list_we.append(i[4:5])
    
print(car_list_we)
# print(car_list_gu)
# Out:
# [['위도'], ['36.93385095'], ['36.9337494'], ['36.93372085'], ['36.93324577'], ['36.93313839'], ['36.93306246'], ['36.93297563'], ['36.93297563'], ['36.93260272'], ['36.93241401'], ['36.9323396'], ['36.9315767'], ['36.93146287'], ['36.93127954'], ['36.93074827'], ['36.93060453'], ['36.93057554'], ['36.93056805'], ['36.93056603'], ['36.92996846'], ['36.92984513'], ['36.92944036'], ['36.92943647'], ['36.92933423'], ['36.92889023'], ['36.92879848'], ['36.92863597'], ['36.92851953'], ['36.92851953'], ['36.92834462'], ['37.43946402'], ['37.43790132'], ['37.34003068'], ['37.43775259'], ['37.34003068'], ['37.41698973'], ['37.39089588'], ['37.3808328'], ['37.34765802'], ['37.39533763'], ['37.44584093'], ['37.44539984'], ['37.38964694'], ['37.38237844'], ['37.34556478'], ['37.38218429'], ['37.35253177'], ['37.35240171'], ['37.34430575'], ['37.35108685'], ['37.38105846'], ['37.44013843'], ['37.34752549'], ['37.39975917'], ['37.43486333'], ['37.35108685'], ['37.38031401'], ['37.36286517'], ['37.34
# ...

# %%
car_list_gu1 =[]
car_list_we1 =[]
for i, e in enumerate(car_list_gu[1:]):
    for j in e:
        try:
            car_list_gu1.append(float(j))
        except:
            pass

for i, e in enumerate(car_list_we[1:]):
    for j in e:
        try:
            car_list_we1.append(float(j))
        except:
            pass

# %%
print(car_list_gu1[:3])
print(car_list_we1[:3])
# Out:
# [129.2462157, 127.4605018, 127.8917746]
# [36.93385095, 36.9337494, 36.93372085]

# %%
list_a = []

for i in zip(car_list_we1, car_list_gu1):
    list_a.append(i)

print(list_a[:2])
#print(di_car)
# np_list_we = np.array(car_list_we1)
# np_list_gu = np.array(car_list_gu1)

# x1 = np_list_gu[0]
# y1 = np_list_we[0]
x1 = list_a[0][0]
y1 = list_a[0][1]

x2 = list_a[1][0]
y2 = list_a[1][1]

dist_np2(np.array[x1, y1],np.array[x2, y2])
print(list_a[0][0])
print(list_a[0][1])
# Out:
# [(36.93385095, 129.2462157), (36.9337494, 127.4605018)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[223], line 19
#      16 x2 = list_a[1][0]
#      17 y2 = list_a[1][1]
# ---> 19 dist_np2(np.array[x1, y1],np.array[x2, y2])
#      20 print(list_a[0][0])
#      21 print(list_a[0][1])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
