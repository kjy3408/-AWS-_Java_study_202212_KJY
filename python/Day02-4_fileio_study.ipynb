# %%
data_list = []
with open('전국건강증진센터표준데이터1.csv') as f:
    for line in f:
        data_list.append(line.split(','))

# %%
data_list = data_list[1:] #list에 담음.

# %%
gu_list = []
si_list = []
for i in data_list:
    address = i[2].lstrip('""') 
    address_list = address.split()
    gu_list.append(address_list[0])
    
# print(gu_list)

# %%
set_gu_list = set(gu_list)

# print(set_gu_list)
for i in set_gu_list:
    print(i, gu_list.count(i))
    
# si_list = []
# si_list.append(set_gu_list)


# gu_list.index("경북")

# gu_list[22] = "경상북도"

print(gu_list)
# Out:
# 대전광역시 10
# 부산광역시 18
# 경상남도 20
# 세종특별자치시 1
# 충청북도 12
# 광주광역시 11
# 경기도 65
# 경북 1
# 경상북도 21
# 제주특별자치도 10
# 대구광역시 8
# 전라남도 20
# 강원도 16
# 서울특별시 26
# 충청남도 16
# 인천광역시 14
# 전라북도 14
# 울산광역시 7
# ...

# %%
gu_list = set(gu_list)

print(gu_list)

for i in set_gu_list:
    print(i, gu_list.count(i))
# Out:
# {'세종특별자치시', '충청북도', '경기도', '대구광역시', '경상북도', '서울특별시', '충청남도', '전라남도', '전라북도', '대전광역시', '부산광역시', '경상남도', '광주광역시', '강원도', '제주특별자치도', '인천광역시', '울산광역시'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 6
#       3 print(gu_list)
#       5 for i in set_gu_list:
# ----> 6     print(i, gu_list.count(i))
#
# AttributeError: 'set' object has no attribute 'count'
